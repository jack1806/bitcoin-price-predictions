# ...                       ...             ...
# 2017-05-02        7155.819506     1387.364538
# 2017-05-03        9080.662263     1391.191083
# 2017-05-04       15323.438111     1438.874083
# 2017-05-05       10011.340375     1452.407598
# 2017-05-06        4421.137105     1462.087358
# 2017-05-07        5658.778876     1479.507188
# 2017-05-08        9529.376554     1577.857367
# 2017-05-09       15684.712985     1668.531916
# 2017-05-10       12610.275544     1666.183326
# 2017-05-11        9677.456760     1758.753220
# 2017-05-12       10944.230354     1742.856764
# 2017-05-13        8137.309667     1672.275548
# 2017-05-14        4820.384299     1724.970595
# 2017-05-15        7540.038439     1683.245492
# 2017-05-16        9568.407001     1668.981792
# 2017-05-17        9828.097549     1751.044995
# 2017-05-18        9501.873694     1792.680292
# 2017-05-19        9628.931573     1869.014530
# 2017-05-20        7895.651657     1957.201009
# 2017-05-21       10521.066471     2016.846321
# 2017-05-22       22711.097860     2130.995949
# 2017-05-23       15831.821065     2188.077328
# 2017-05-24       18815.565891     2336.612637
# 2017-05-25       45509.760207     2515.712515
# 2017-05-26       28322.048733     2303.644267
# 2017-05-27       30699.136205     1966.300193
# 2017-05-28       13264.307050     2071.396826
# 2017-05-29       10327.057628     2145.914241
# 2017-05-30       12734.874558     2217.294593
# 2017-05-31       14413.324651     2139.402594
#
# [1979 rows x 7 columns]

# %%
# PLOTS
fig = plt.figure(figsize=[15, 7])
plt.suptitle('Bitcoin exchanges, mean USD', fontsize=22)

plt.subplot(221)
plt.plot(df.Weighted_Price, '-', label='By Days')
plt.legend()

plt.subplot(222)
plt.plot(df_month.Weighted_Price, '-', label='By Months')
plt.legend()

plt.subplot(223)
plt.plot(df_Q.Weighted_Price, '-', label='By Quarters')
plt.legend()

plt.subplot(224)
plt.plot(df_year.Weighted_Price, '-', label='By Years')
plt.legend()

# plt.tight_layout()
plt.show()

# %% [markdown]
# I will predict bitcoin prices by months.

# %% [markdown]
# ## Stationarity check and STL-decomposition of the series

# %%
plt.figure(figsize=[15,7])
sm.tsa.seasonal_decompose(df_month.Weighted_Price).plot()
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.Weighted_Price)[1])
plt.show()
# Out:
# Dickey–Fuller test: p=0.997760

# %% [markdown]
# The series are not stationary.

# %% [markdown]
# ## Box-Cox Transformations

# %%
# Box-Cox Transformations
df_month['Weighted_Price_box'], lmbda = stats.boxcox(df_month.Weighted_Price)
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.Weighted_Price)[1])
# Out:
# Dickey–Fuller test: p=0.997760

# %% [markdown]
# The series are not stationary.

# %% [markdown]
# ## Seasonal differentiation

# %%
# Seasonal differentiation
df_month['prices_box_diff'] = df_month.Weighted_Price_box - df_month.Weighted_Price_box.shift(12)
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.prices_box_diff[12:])[1])
# Out:
# Dickey–Fuller test: p=0.137240

# %% [markdown]
# The series are not stationary.

# %% [markdown]
# ## Regular differentiation

# %%
# Regular differentiation
df_month['prices_box_diff2'] = df_month.prices_box_diff - df_month.prices_box_diff.shift(1)
plt.figure(figsize=(15,7))

# STL-decomposition
sm.tsa.seasonal_decompose(df_month.prices_box_diff2[13:]).plot()   
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.prices_box_diff2[13:])[1])

plt.show()
# Out:
# Dickey–Fuller test: p=0.014538

# %% [markdown]
# The series are stationary.

# %% [markdown]
# ## Model Selection

# %%
# Initial approximation of parameters using Autocorrelation and Partial Autocorrelation Plots
plt.figure(figsize=(15,7))
ax = plt.subplot(211)
sm.graphics.tsa.plot_acf(df_month.prices_box_diff2[13:].values.squeeze(), lags=48, ax=ax)
ax = plt.subplot(212)
sm.graphics.tsa.plot_pacf(df_month.prices_box_diff2[13:].values.squeeze(), lags=48, ax=ax)
plt.tight_layout()
plt.show()

# %%
# Initial approximation of parameters
Qs = range(0, 2)
qs = range(0, 3)
Ps = range(0, 3)
ps = range(0, 3)
D=1
d=1
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)

# Model Selection
results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')
for param in parameters_list:
    try:
        model=sm.tsa.statespace.SARIMAX(df_month.Weighted_Price_box, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-fc70c7721226> in <module>
#      17     try:
#      18         model=sm.tsa.statespace.SARIMAX(df_month.Weighted_Price_box, order=(param[0], d, param[1]),
# ---> 19                                         seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
#      20     except ValueError:
#      21         print('wrong parameters:', param)
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/statespace/mlemodel.py in fit(self, start_params, transformed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, **kwargs)
#     475         else:
#     476             res = self.smooth(mlefit.params, transformed=False,
# --> 477                               cov_type=cov_type, cov_kwds=cov_kwds)
#     478
#     479             res.mlefit = mlefit
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/statespace/mlemodel.py in smooth(self, params, transformed, complex_step, cov_type, cov_kwds, return_ssm, results_class, results_wrapper_class, **kwargs)
#     596         return self._wrap_results(params, result, return_ssm, cov_type,
#     597                                   cov_kwds, results_class,
# --> 598                                   results_wrapper_class)
#     599
#     600     _loglike_param_names = ['transformed', 'complex_step']
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/statespace/mlemodel.py in _wrap_results(self, params, result, return_raw, cov_type, cov_kwds, results_class, wrapper_class)
#     502                 wrapper_class = self._res_classes['fit'][1]
#     503
# --> 504             res = results_class(self, params, result, **result_kwargs)
#     505             result = wrapper_class(res)
#     506         return result
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/statespace/sarimax.py in __init__(self, model, params, filter_results, cov_type, **kwargs)
#    1725                  **kwargs):
#    1726         super(SARIMAXResults, self).__init__(model, params, filter_results,
# -> 1727                                              cov_type, **kwargs)
#    1728
#    1729         self.df_resid = np.inf  # attribute required for wald tests
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/statespace/mlemodel.py in __init__(self, model, params, results, cov_type, cov_kwds, **kwargs)
#    1575             self._rank = None
#    1576             self._get_robustcov_results(cov_type=cov_type, use_self=True,
# -> 1577                                         **cov_kwds)
#    1578         except np.linalg.LinAlgError:
#    1579             self._rank = 0
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/statespace/mlemodel.py in _get_robustcov_results(self, cov_type, **kwargs)
#    1701                 ' matrix (%s) described in Harvey (1989).' % approx_type_str)
#    1702         elif self.cov_type == 'opg':
# -> 1703             res.cov_params_default = res.cov_params_opg
#    1704             res.cov_kwds['description'] = (
#    1705                 'Covariance matrix calculated using the outer product of'
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tools/decorators.py in __get__(self, obj, type)
#      95         if _cachedval is None:
#      96             # Call the "fget" function
# ---> 97             _cachedval = self.fget(obj)
#      98             # Set the attribute in obj
#      99             # print("Setting %s in cache to %s" % (name, _cachedval))
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/statespace/mlemodel.py in cov_params_opg(self)
#    1815         """
#    1816         return self._cov_params_opg(self._cov_approx_complex_step,
# -> 1817                                     self._cov_approx_centered)
#    1818
#    1819     @cache_readonly
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/statespace/mlemodel.py in _cov_params_opg(self, approx_complex_step, approx_centered)
#    1799                                         transformed=True,
#    1800                                         approx_complex_step=approx_complex_step,
# -> 1801                                         approx_centered=approx_centered)
#    1802
#    1803         (neg_cov, singular_values) = pinv_extended(evaluated_hessian)
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/statespace/mlemodel.py in _hessian_opg(self, params, **kwargs)
#    1226         information matrix
#    1227         """
# -> 1228         return -self.opg_information_matrix(params, **kwargs)
#    1229
#    1230     def _hessian_finite_difference(self, params, approx_centered=False,
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/statespace/mlemodel.py in opg_information_matrix(self, params, transformed, approx_complex_step, **kwargs)
#     929         score_obs = self.score_obs(params, transformed=transformed,
#     930                                    approx_complex_step=approx_complex_step,
# --> 931                                    **kwargs).transpose()
#     932         return (
#     933             np.inner(score_obs, score_obs) /
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/statespace/mlemodel.py in score_obs(self, params, method, transformed, approx_complex_step, approx_centered, **kwargs)
#    1132             kwargs['transformed'] = True
#    1133             score = approx_fprime_cs(params, self.loglikeobs, epsilon=epsilon,
# -> 1134                                      kwargs=kwargs)
#    1135         elif method == 'approx':
#    1136             kwargs['transformed'] = transformed
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tools/numdiff.py in approx_fprime_cs(x, f, epsilon, args, kwargs)
#     200     # TODO: see if this can be vectorized, but usually dim is small
#     201     partials = [f(x+ih, *args, **kwargs).imag / epsilon[i]
# --> 202                 for i, ih in enumerate(increments)]
#     203     return np.array(partials).T
#     204
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tools/numdiff.py in <listcomp>(.0)
#     200     # TODO: see if this can be vectorized, but usually dim is small
#     201     partials = [f(x+ih, *args, **kwargs).imag / epsilon[i]
# --> 202                 for i, ih in enumerate(increments)]
#     203     return np.array(partials).T
#     204
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/statespace/mlemodel.py in loglikeobs(self, params, transformed, complex_step, **kwargs)
#     690             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     691
# --> 692         self.update(params, transformed=True, complex_step=complex_step)
#     693
#     694         return self.ssm.loglikeobs(complex_step=complex_step, **kwargs)
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/statespace/sarimax.py in update(self, params, transformed, complex_step)
#    1674         # Initialize
#    1675         if not self._manual_initialization:
# -> 1676             self.initialize_state(complex_step=complex_step)
#    1677
#    1678         return params
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/statespace/sarimax.py in initialize_state(self, variance, complex_step)
#     733             selection_stationary = self.ssm['selection', start:end, :, 0]
#     734             selected_state_cov_stationary = np.dot(
# --> 735                 np.dot(selection_stationary, self.ssm['state_cov', :, :, 0]),
#     736                 selection_stationary.T)
#     737             initial_state_cov_stationary = solve_discrete_lyapunov(
#
# KeyboardInterrupt:

# %%
# Best Models
result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
print(best_model.summary())

# %% [markdown]
# ## Analysis of residues

# %%
# STL-decomposition
plt.figure(figsize=(15,7))
plt.subplot(211)
best_model.resid[13:].plot()
plt.ylabel(u'Residuals')
ax = plt.subplot(212)
sm.graphics.tsa.plot_acf(best_model.resid[13:].values.squeeze(), lags=48, ax=ax)

print("Dickey–Fuller test:: p=%f" % sm.tsa.stattools.adfuller(best_model.resid[13:])[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# It`s OK.

# %% [markdown]
# ## Prediction

# %%
# Inverse Box-Cox Transformation Function
def invboxcox(y,lmbda):
   if lmbda == 0:
      return(np.exp(y))
   else:
      return(np.exp(np.log(lmbda*y+1)/lmbda))

# %%
# Prediction
df_month2 = df_month[['Weighted_Price']]
date_list = [datetime(2017, 6, 30), datetime(2017, 7, 31), datetime(2017, 8, 31), datetime(2017, 9, 30), 
             datetime(2017, 10, 31), datetime(2017, 11, 30), datetime(2017, 12, 31), datetime(2018, 1, 31),
             datetime(2018, 1, 28)]
future = pd.DataFrame(index=date_list, columns= df_month.columns)
df_month2 = pd.concat([df_month2, future])
df_month2['forecast'] = invboxcox(best_model.predict(start=0, end=75), lmbda)
plt.figure(figsize=(15,7))
df_month2.Weighted_Price.plot()
df_month2.forecast.plot(color='r', ls='--', label='Predicted Weighted_Price')
plt.legend()
plt.title('Bitcoin exchanges, by months')
plt.ylabel('mean USD')
plt.show()
